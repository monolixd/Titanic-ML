# %%
import pandas as pd

df = pd.read_csv('dataset/train.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### วิธีดูค่าว่างใน DataFrame

# %%
# นับจำนวน Missing Values ในแต่ละคอลัมน์
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 5))

sns.histplot(df['Age'].dropna(),bins=30,kde=False)

#ตั้งชื่อกราฟ
plt.title('Age Distribution of titanic passengers')
plt.xlabel('Age')
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## วิเคราะห์อัตราการรอดชีวิต

# %%
survivals_count = df['Survived'].value_counts()

# สร้างกราฟแท่งแสดงจำนวนผู้รอดชีวิตและผู้ไม่รอดชีวิต
plt.figure(figsize=(6, 4))
sns.barplot(x=survivals_count.index, y=survivals_count.values, palette="viridis")

# ตั้งชื่อกราฟ
plt.title('Survival count of titanic passengers')
plt.xticks([0,1],['Not Survived','Survived'])
plt.xlabel("Survival Status")
plt.ylabel("Count")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6208\2901617632.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survivals_count.index, y=survivals_count.values, palette="viridis")

# %% [markdown]
# ### วิเคราะห์อัตราการรอดชีวิตแยกตามเพศ

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x="Sex", y="Survived", data=df, palette="coolwarm")

plt.title('Suvive Rate By Gender')
plt.xlabel("Gender")
plt.ylabel("Survival Rate")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6208\2413769014.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Sex", y="Survived", data=df, palette="coolwarm")

# %% [markdown]
# ### วิเคราะห์อัตราการรอดชีวิตตามชั้นโดยสาร

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x="Pclass", y="Survived", data=df, palette="muted")

plt.title('Suvive Rate By Passenger class')
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6208\3364378172.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=df, palette="muted")

# %% [markdown]
# ### วิเคราะห์ราคาตั๋วกับโอกาสรอดชีวิต

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x="Pclass", y="Survived", data=df, palette="muted")
plt.title("Survival Rate by Passenger Class")

plt.xlabel("Passenger Class")
plt.ylabel("Fare Price")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6208\2543827996.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=df, palette="muted")

# %% [markdown]
# ### วิเคราะห์จำนวนครอบครัวบนเรือ

# %%
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

plt.figure(figsize=(6, 4))
sns.barplot(x="FamilySize", y="Survived", data=df, palette="muted")

plt.title("Survival Rate by Family Size")
plt.xlabel("Family Size")
plt.ylabel("Survival Rate")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6208\3985895744.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="FamilySize", y="Survived", data=df, palette="muted")
